# %% [markdown]
# ##### import numpy as nd
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# data=pd.read_excel("sample.xlsx")
# print(data)

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2       3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3       4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4       5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2018-110422 2018-01-21 2018-01-23    Second Class
# 9990    9991  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9991    9992  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9992    9993  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9993    9994  CA-2021-119914 2021-05-04 2021-05-09    Second Class
#
#      Customer ID     Customer Name   Segment Country/Region         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.describe(include="all")
# Out:
#              Row ID        Order ID                     Order Date  \
# count   9994.000000            9994                           9994
# unique          NaN            5009                            NaN
# top             NaN  CA-2021-100111                            NaN
# freq            NaN              14                            NaN
# mean    4997.500000             NaN  2020-04-30 00:07:03.614168576
# min        1.000000             NaN            2018-01-03 00:00:00
# 25%     2499.250000             NaN            2019-05-23 00:00:00
# 50%     4997.500000             NaN            2020-06-26 00:00:00
# 75%     7495.750000             NaN            2021-05-14 00:00:00
# max     9994.000000             NaN            2021-12-30 00:00:00
# std     2885.163629             NaN                            NaN
#
#                             Ship Date       Ship Mode Customer ID  \
# count                            9994            9994        9994
# ...

# %%
data[data["State"].isnull()].any(axis=1)
# Out:
# C:\Users\prema\AppData\Local\Temp\ipykernel_13016\2606945855.py:1: FutureWarning: 'any' with datetime64 dtypes is deprecated and will raise in a future version. Use (obj != pd.Timestamp(0)).any() instead.
#   data[data["State"].isnull()].any(axis=1)
# 480    True
# 534    True
# 593    True
# 664    True
# dtype: bool

# %%
data.loc[591:595]
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 591     592  US-2020-156986 2020-03-20 2020-03-24  Standard Class    ZC-21910
# 592     593  CA-2018-135405 2018-01-09 2018-01-13  Standard Class    MS-17830
# 593     594  CA-2018-135405 2018-01-09 2018-01-13  Standard Class    MS-17830
# 594     595  CA-2018-131450 2018-08-08 2018-08-15  Standard Class    LR-16915
# 595     596  CA-2018-131450 2018-08-08 2018-08-15  Standard Class    LR-16915
#
#         Customer Name   Segment Country/Region       City  ... Postal Code  \
# 591  Zuschuss Carroll  Consumer  United States      Salem  ...     97301.0
# 592     Melanie Seite  Consumer  United States     Laredo  ...     78041.0
# 593     Melanie Seite  Consumer  United States     Laredo  ...     78041.0
# 594      Lena Radford  Consumer  United States  San Diego  ...     92024.0
# 595      Lena Radford  Consumer  United States  San Diego  ...     92024.0
#
# ...

# %%
data["Sales"]=data["Sales"].fillna(data["Sales"].mean)

# %%
data.loc[590:596]
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 590     591  US-2020-156986 2020-03-20 2020-03-24  Standard Class    ZC-21910
# 591     592  US-2020-156986 2020-03-20 2020-03-24  Standard Class    ZC-21910
# 592     593  CA-2018-135405 2018-01-09 2018-01-13  Standard Class    MS-17830
# 593     594  CA-2018-135405 2018-01-09 2018-01-13  Standard Class    MS-17830
# 594     595  CA-2018-131450 2018-08-08 2018-08-15  Standard Class    LR-16915
# 595     596  CA-2018-131450 2018-08-08 2018-08-15  Standard Class    LR-16915
# 596     597  CA-2018-131450 2018-08-08 2018-08-15  Standard Class    LR-16915
#
#         Customer Name   Segment Country/Region       City  ... Postal Code  \
# 590  Zuschuss Carroll  Consumer  United States      Salem  ...     97301.0
# 591  Zuschuss Carroll  Consumer  United States      Salem  ...     97301.0
# 592     Melanie Seite  Consumer  United States     Laredo  ...     78041.0
# ...

# %%
data[data.isnull().any(axis=1)]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 32        33  US-2019-150630 2019-09-17 2019-09-21  Standard Class
# 33        34  US-2019-150630 2019-09-17 2019-09-21  Standard Class
# 61        62  CA-2020-111682 2020-06-17 2020-06-18     First Class
# 116      117  CA-2018-115259 2018-08-25 2018-08-27    Second Class
# 195      196  CA-2018-140004 2018-03-21 2018-03-25  Standard Class
# 238      239  CA-2020-157749 2020-06-04 2020-06-09    Second Class
# 274      275  CA-2021-118136 2021-09-16 2021-09-17     First Class
# 301      302  CA-2020-142545 2020-10-28 2020-11-03  Standard Class
# 329      330  US-2020-141544 2020-08-30 2020-09-01     First Class
# 349      350  CA-2020-129714 2020-09-01 2020-09-03     First Class
# 359      360  CA-2021-155698 2021-03-08 2021-03-11     First Class
# 385      386  US-2019-168935 2019-11-27 2019-12-02  Standard Class
# 386      387  CA-2019-122756 2019-12-03 2019-12-07  Standard Class
# ...

# %%
data.isnull().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              4
# Postal Code       22
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           1
# Discount           0
# Profit             5
# dtype: int64

# %%
data.replace("$261.96",261.96,inplace=True)

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State                     object
# Postal Code              float64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                     object
# Quantity                 float64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
data.loc[780:782]
# Out:
#      Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 780     781  CA-2019-144267 2019-08-21 2019-08-23   First Class    NZ-18565
# 781     782  US-2019-157014 2019-10-03 2019-10-06  Second Class    BM-11785
# 782     783  US-2019-157014 2019-10-03 2019-10-06  Second Class    BM-11785
#
#      Customer Name      Segment Country/Region           City  ...  \
# 780  Nick Zandusky  Home Office  United States  San Francisco  ...
# 781    Bryan Mills     Consumer  United States       Columbus  ...
# 782    Bryan Mills     Consumer  United States       Columbus  ...
#
#     Postal Code  Region       Product ID         Category Sub-Category  \
# 780     94110.0    West  OFF-PA-10003657  Office Supplies        Paper
# 781     43229.0    East  OFF-BI-10001098  Office Supplies      Binders
# 782     43229.0    East  TEC-AC-10002167       Technology  Accessories
#
#                                           Product Name Sales Quantity  \
# ...

# %%
kk=data.isnull().sum(axis=1)
print(kk)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9989    0
# 9990    0
# 9991    0
# 9992    0
# 9993    0
# Length: 9994, dtype: int64

# %%
data.fillna(method="ffill",inplace=True)
# Out:
# C:\Users\prema\AppData\Local\Temp\ipykernel_4276\1830165551.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method="ffill",inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.pairplot(data=data)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=data["Ship Mode"],y=data["Profit"])
plt.show()

# %%
rr=data.groupby("Segment")["Region"].count()

print(rr)
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Region, dtype: int64

# %%
df1=data.groupby("Segment")["Region"].count()
df1
plt.pie(df1,autopct="%0.2f%%",labels=df1.index,explode=(0.1,0,0))
plt.show()

# %%
sns.scatterplot(x=data["Category"],y=data["Profit"])
plt.show()
